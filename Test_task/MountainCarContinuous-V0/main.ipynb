# %%
from train import main

from eval import eval_main

# %%
main()
# Out:
# Step: 1000, Reward mean: -17.34374999999971, Reward std: 0.0
# Step: 2000, Reward mean: 93.72527777777778, Reward std: 0.23739260079787874
# Step: 3000, Reward mean: 75.56347222222223, Reward std: 38.12991735794566
# Step: 4000, Reward mean: 94.76027777777777, Reward std: 0.16008437204437334
# Step: 5000, Reward mean: 94.09527777777778, Reward std: 0.5353157600547226
# Step: 6000, Reward mean: -6.243749999999912, Reward std: 0.0
# Step: 7000, Reward mean: -6.243749999999912, Reward std: 0.0
# Step: 8000, Reward mean: -61.10291666666641, Reward std: 0.35386517668682843
# Step: 9000, Reward mean: 95.98458333333333, Reward std: 0.13132853323621316
# Step: 10000, Reward mean: -33.99374999999965, Reward std: 0.0
# Step: 11000, Reward mean: -7.566111111111267, Reward std: 3.293348328051145
# Step: 12000, Reward mean: 36.84625, Reward std: 45.15027886980993
# Step: 13000, Reward mean: -2.774999999999991, Reward std: 0.0
# ...

# %%
eval_main(['agent_0'])
# Out:
# agent_0 96.02690972222221 0.21413978734533448 [95.99236111111111, 96.05069444444445, 95.99236111111111, 95.99930555555555, 96.5798611111111, 96.13749999999999, 96.01597222222222, 95.8625, 96.19027777777777, 96.15347222222222, 95.83055555555555, 95.84652777777778, 96.57222222222222, 95.84791666666666, 95.8625, 95.9673611111111, 95.76666666666667, 96.00069444444443, 95.86736111111111, 96.00208333333333]
# _____________________
# agent_0 96.06510416666667 0.20822379933052496 [95.99236111111111, 96.00486111111111, 95.99444444444444, 96.01319444444444, 95.84166666666667, 95.89236111111111, 95.76666666666667, 95.84791666666666, 96.05416666666666, 96.08680555555556, 96.18888888888888, 95.90972222222221, 96.12430555555555, 96.16180555555555, 95.93888888888888, 96.58055555555555, 96.12222222222222, 96.59166666666667, 96.18888888888888, 96.00069444444443]
# _____________________
# ...

# %% [markdown]
# К сожалению алгоритм DDPG, который по идее более уместен тут, показывал более плохие результаты, поэтому пришлось оставлять версию с дискретизацией.
